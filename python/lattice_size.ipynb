# %%
mx = 6.95
my = 6.4
mz = 3.1

# %%
cl = 256 / mx
a = mx*cl * my*cl * mz*cl

# %%
cl = 320 / mx
b = mx*cl * my*cl * mz*cl
b/a
# Out:
# 1.9531249999999998

# %%
cl = (512+32) / mx
c = mx*cl * my*cl * mz*cl
c/a
# Out:
# 9.595703124999998
